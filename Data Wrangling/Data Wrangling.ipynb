# %% [markdown]
# # 🎓 Data Wrangling

# %% [markdown]
# Nesta prática faremos a análise dos dados da Covid19 no Brasil até o momento. Algumas células estão preenchidas para auxiliar na leitura dos dados. Faça o que se pede.

# %%
# Bibliotecas utilizadas
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn')
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Extraia os dados baixados de https://covid.saude.gov.br/

# %%
# Código para extrair os arquivos
csv1 = pd.read_csv('C:/Users/vinip/Downloads/HIST_PAINEL_COVIDBR_2020_Parte1_17ago2022.csv',sep=';', index_col=['data'])
csv2 = pd.read_csv('C:/Users/vinip/Downloads/HIST_PAINEL_COVIDBR_2020_Parte2_17ago2022.csv',sep=';', index_col=['data'])
csv3 = pd.read_csv('C:/Users/vinip/Downloads/HIST_PAINEL_COVIDBR_2021_Parte1_17ago2022.csv',sep=';', index_col=['data'])
csv4 = pd.read_csv('C:/Users/vinip/Downloads/HIST_PAINEL_COVIDBR_2021_Parte2_17ago2022.csv',sep=';', index_col=['data'])
csv5 = pd.read_csv('C:/Users/vinip/Downloads/HIST_PAINEL_COVIDBR_2022_Parte1_17ago2022.csv',sep=';', index_col=['data'])
csv6 = pd.read_csv('C:/Users/vinip/Downloads/HIST_PAINEL_COVIDBR_2022_Parte2_17ago2022.csv',sep=';', index_col=['data'])

# %% [markdown]
# Faça aqui o concatenamento das linhas dos `dataframes` da lista em um `dataframe` único.

# %%
arquivos = pd.concat([csv1, csv2, csv3, csv4, csv5, csv6], axis=0)
arquivos
# Out:
#                   regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# data
# 2020-02-25        Brasil    NaN       NaN     76       NaN             NaN
# 2020-02-26        Brasil    NaN       NaN     76       NaN             NaN
# 2020-02-27        Brasil    NaN       NaN     76       NaN             NaN
# 2020-02-28        Brasil    NaN       NaN     76       NaN             NaN
# 2020-02-29        Brasil    NaN       NaN     76       NaN             NaN
# ...                  ...    ...       ...    ...       ...             ...
# 2022-08-13  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 2022-08-14  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 2022-08-15  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 2022-08-16  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 2022-08-17  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
# ...

# %% [markdown]
# Nosso objetivo é mostrar somente os valores a nível de Brasil. Faça um filtro das linhas baseado na coluna `regiao` somente para a correspondência `Brasil`. Salve este filtro em um `Dataframe`.

# %%
csv_BR = arquivos[arquivos['regiao'] == 'Brasil']
csv_BR
# Out:
#             regiao estado municipio  coduf  codmun  codRegiaoSaude  \
# data
# 2020-02-25  Brasil    NaN       NaN     76     NaN             NaN
# 2020-02-26  Brasil    NaN       NaN     76     NaN             NaN
# 2020-02-27  Brasil    NaN       NaN     76     NaN             NaN
# 2020-02-28  Brasil    NaN       NaN     76     NaN             NaN
# 2020-02-29  Brasil    NaN       NaN     76     NaN             NaN
# ...            ...    ...       ...    ...     ...             ...
# 2022-08-13  Brasil    NaN       NaN     76     NaN             NaN
# 2022-08-14  Brasil    NaN       NaN     76     NaN             NaN
# 2022-08-15  Brasil    NaN       NaN     76     NaN             NaN
# 2022-08-16  Brasil    NaN       NaN     76     NaN             NaN
# 2022-08-17  Brasil    NaN       NaN     76     NaN             NaN
#
#            nomeRegiaoSaude  semanaEpi  populacaoTCU2019  casosAcumulado  \
# data
# 2020-02-25             NaN        9.0       210147125.0             0.0
# ...

# %% [markdown]
# Selecione somente as colunas 'casosAcumulado', 'casosNovos', 'obitosAcumulado', 'obitosNovos' do `Dataframe` e descarte as demais.

# %%
csv_BR = csv_BR[['casosAcumulado', 'casosNovos', 'obitosAcumulado', 'obitosNovos']]
csv_BR
# Out:
#             casosAcumulado  casosNovos  obitosAcumulado  obitosNovos
# data
# 2020-02-25             0.0         0.0              0.0          0.0
# 2020-02-26             1.0         1.0              0.0          0.0
# 2020-02-27             1.0         0.0              0.0          0.0
# 2020-02-28             1.0         0.0              0.0          0.0
# 2020-02-29             2.0         1.0              0.0          0.0
# ...                    ...         ...              ...          ...
# 2022-08-13      34165857.0     17726.0         681400.0        147.0
# 2022-08-14      34170286.0      4429.0         681437.0         37.0
# 2022-08-15      34178240.0      7954.0         681557.0        120.0
# 2022-08-16      34201280.0     23040.0         681763.0        206.0
# 2022-08-17      34223207.0     21927.0         682010.0        247.0
#
# [905 rows x 4 columns]

# %% [markdown]
# Faça aqui o gráfico de 'casosAcumulado' ao longo dos dias desde o começo da pandemia.

# %%
csv_BR['casosAcumulado'].plot(color='firebrick', linewidth=10, figsize=(60,30))

plt.xticks(fontsize=50)
plt.yticks(fontsize=50)
plt.legend('')

plt.title('Casos Acumulados ao longo dos dias desde o começo da pandemia', fontsize=70)
plt.xlabel('Data', fontsize=70)
plt.ylabel('Casos Acumulados', fontsize=70)
# Out:
# Text(0, 0.5, 'Casos Acumulados')

# %% [markdown]
# Faça aqui o gráfico de 'obitosAcumulado' ao longo dos dias desde o começo da pandemia.

# %%
csv_BR['obitosAcumulado'].plot(color='firebrick', linewidth=10, figsize=(60,30))

plt.xticks(fontsize=50)
plt.yticks(fontsize=50)
plt.legend('')

plt.title('Obitos Acumulados ao longo dos dias desde o começo da pandemia', fontsize=70)
plt.xlabel('Data', fontsize=70)
plt.ylabel('Obitos Acumulados', fontsize=70)
# Out:
# Text(0, 0.5, 'Obitos Acumulados')

# %% [markdown]
# Qual a quantidade total de óbitos por Covid19 no Brasil a partir da análise desses dados?

# %%
csv_BR['obitosAcumulado'][-1]
# Out:
# 682010.0

# %% [markdown]
# Crie uma coluna com a media móvel dos 'casosNovos' e 'obitosNovos'. Use uma janela de 7 dias para o cálculo da média móvel.
#
# Use o seguinte exemplo como referência para calcular a média móvel.
#
# ```python
#
# df['nomeColuna'].rolling(Janela).mean()
# ```

# %%
csv_BR['media_movel_casosNovos'] = csv_BR['casosNovos'].rolling(7).mean()
csv_BR
# Out:
#             casosAcumulado  casosNovos  obitosAcumulado  obitosNovos  \
# data
# 2020-02-25             0.0         0.0              0.0          0.0
# 2020-02-26             1.0         1.0              0.0          0.0
# 2020-02-27             1.0         0.0              0.0          0.0
# 2020-02-28             1.0         0.0              0.0          0.0
# 2020-02-29             2.0         1.0              0.0          0.0
# ...                    ...         ...              ...          ...
# 2022-08-13      34165857.0     17726.0         681400.0        147.0
# 2022-08-14      34170286.0      4429.0         681437.0         37.0
# 2022-08-15      34178240.0      7954.0         681557.0        120.0
# 2022-08-16      34201280.0     23040.0         681763.0        206.0
# 2022-08-17      34223207.0     21927.0         682010.0        247.0
#
#             media_movel_casosNovos
# data
# 2020-02-25                     NaN
# 2020-02-26                     NaN
# ...

# %%
csv_BR['media_movel_obitosNovos'] = csv_BR['obitosNovos'].rolling(7).mean()
csv_BR
# Out:
#             casosAcumulado  casosNovos  obitosAcumulado  obitosNovos  \
# data
# 2020-02-25             0.0         0.0              0.0          0.0
# 2020-02-26             1.0         1.0              0.0          0.0
# 2020-02-27             1.0         0.0              0.0          0.0
# 2020-02-28             1.0         0.0              0.0          0.0
# 2020-02-29             2.0         1.0              0.0          0.0
# ...                    ...         ...              ...          ...
# 2022-08-13      34165857.0     17726.0         681400.0        147.0
# 2022-08-14      34170286.0      4429.0         681437.0         37.0
# 2022-08-15      34178240.0      7954.0         681557.0        120.0
# 2022-08-16      34201280.0     23040.0         681763.0        206.0
# 2022-08-17      34223207.0     21927.0         682010.0        247.0
#
#             media_movel_casosNovos  media_movel_obitosNovos
# data
# 2020-02-25                     NaN                      NaN
# ...

# %% [markdown]
# Faça um gráfico da evolução dos casos e sua média móvel. Use a coluna 'casosNovos' para a evolução diária de casos e a coluna referente à média móvel de casos que você calculou.

# %%
csv_BR['casosNovos'].plot(color='black', linewidth=10, figsize=(60,30))
csv_BR['media_movel_casosNovos'].plot(color='lime', linewidth=7)

plt.xticks(fontsize=50)
plt.yticks(fontsize=50)
plt.legend('')

plt.title('Evolução dos Casos de COVID-19 com a Média Móvel', fontsize=20)
plt.xlabel('Data', fontsize=70)
plt.ylabel('Casos Novos', fontsize=70)
# Out:
# Text(0, 0.5, 'Casos Novos')

# %% [markdown]
# Faça um gráfico da evolução dos óbitos e sua média móvel. Use a coluna 'obitosNovos' para a evolução diária de óbitos e a coluna referente à média móvel de óbitos que você calculou.

# %%
csv_BR['obitosNovos'].plot(color='black', linewidth=10, figsize=(60,30))
csv_BR['media_movel_obitosNovos'].plot(color='lime', linewidth=7)

plt.xticks(fontsize=50)
plt.yticks(fontsize=50)
plt.legend('')

plt.title('Evolução dos Obitos de COVID-19 com a Média Móvel', fontsize=20)
plt.xlabel('Data', fontsize=70)
plt.ylabel('Obitos Novos', fontsize=70)
# Out:
# Text(0, 0.5, 'Obitos Novos')

# %% [markdown]
# Qual o dia com o maior registro de óbitos e qual é esse valor?

# %%
csv_BR[csv_BR['obitosNovos'] == csv_BR['obitosNovos'].max()]
# Out:
#             casosAcumulado  casosNovos  obitosAcumulado  obitosNovos  \
# data
# 2021-04-08      13279857.0     86652.0         345025.0       4249.0
#
#             media_movel_casosNovos  media_movel_obitosNovos
# data
# 2021-04-08                 62859.0              2820.142857

# %% [markdown]
# Qual o dia com a maior média móvel de óbitos e qual é esse valor?

# %%
csv_BR[csv_BR['media_movel_obitosNovos'] == csv_BR['media_movel_obitosNovos'].max()]
# Out:
#             casosAcumulado  casosNovos  obitosAcumulado  obitosNovos  \
# data
# 2021-04-12      13517808.0     35785.0         354617.0       1480.0
#
#             media_movel_casosNovos  media_movel_obitosNovos
# data
# 2021-04-12            72029.571429              3123.571429
